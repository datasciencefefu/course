# %% [markdown]
# <a href="https://colab.research.google.com/github/datasciencefefu/course/blob/main/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Заключение

# %% [markdown]
# Анализом данных человечество занимается с незапямятных времен. Люди всегда сопоставляли и анализировали имеющиеся данные, пытаясь извлечь из них новую полезную информацию - знание. Ученые кропотливо и аккуратно производили наблюдения, фиксировали результаты и обнаруживали аналитические зависимости одних величин от других. Так, основываясь на данных, полученных путем измерения движения планет, совершил открытие закона всемирного тяготения Исаак Ньютон. Он использовал в том числе астрономические наблюдения, сделанные веком ранее датским астрономом Тихо Браге, который измерил положение всех на тот момент известных планет и записал их координаты, но не сумел окончательно сформулировать закон движения планет относительно Солнца.
#
# Если раньше сбор материала, его систематизация, анализ и выдвижение гипотез производились вручную и требовали большого количества времени и усилий, то сегодня на вооружении ученых и специалистов по обработке данных новые мощные вычислительные инструменты. Для обозначения отрасли знаний и специалистов, которые должны разбираться в огромных массивах больших данных, был введен термин «наука о данных» (термин Data Science прозвучал только в 1974-м).
#
# Современную науку о данных можно разделить на два больших раздела: анализ данных (Data Science) и машинное обучение (Machine Learning). С инструментами аналитиков данных (дата-сайентистов) вы познакомились в этом пособии: узнали что такое распределение, познакомились с базовой проверкой данных, научились строить гистограммы и находить взаимосвязи между разными значениями путем построения графиков разброса (scatter) и матриц корреляции. На практических примерах вы изучили методы сбора и предобработки данных, поняли как статистика и теория вероятностей помогают решать задачи бизнеса. Теперь вы знаете, что аналитики не только производят расчёты, но и осуществляют поиск необычных явлений, артефактов и ошибок в данных. В этом дата-сайентистам помогают построение и анализ графиков: визуальное представление позволяет буквально заглянуть в данные, обнаружить проблемы и сделать зачастую неожиданные выводы, которые могут принести едва ли не больше пользы, чем решение первоначальной задачи. Специалисты по машинному обучению занимаются другим классом задач — обучают машины делать автоматические предсказания. Например, предугадывать изменение спроса на тот или иной товар в зависимости от различных факторов. Если вам интересно изучить методы машинного обучения, то знакомство с этим подразделом науки о данных лучше всего начать с библиотеки NumPy.  NumPy — это  библиотека машинного обучения Python предоставляет возможности для обработки данных и чисел. Возможности библиотеки позволяют создать объект N-мерного массива, в который пользователи могут помещать свои данные, и предлагают функции преобразования этих данных. Объект массива также можно легко адаптировать к другим базам данных, что делает его хорошим инструментом для машинного обучения. Краткий обзор функциональных возможностей библиотеки NumPy приведен в Приложении.
#
# Профессию дата-сайентиста из года в год называют одной из самых востребованных. Умение собирать, обрабатывать и интерпретировать информацию пригодится в любой сфере — неважно, работаете ли вы в ретейле или медицине. Все больше компаний нанимают аналитиков и готовы хорошо им платить. По запросу «аналитик данных» на hh.ru есть порядка 10 тысяч вакансий: junior может рассчитывать на зарплату от 70 тысяч, опытный специалист (senior) — до 200 тысяч рублей. Аналитики помогают бизнесу развиваться эффективнее. Согласно опросам, 65% компаний не в состоянии проанализировать имеющиеся данные, при этом 89% из них уверены, что если бы они могли это сделать, то получили бы конкурентное преимущество. Может показаться, что аналитик данных не самая творческая профессия: ему каждый день приходится заниматься рутинным сбором и анализом. Однако именно его работа может дать удивительные результаты — обнаружить проблемы, предсказать будущее, сделать явным то, что никто иначе бы не узнал.
